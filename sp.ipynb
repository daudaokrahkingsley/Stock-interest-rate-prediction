# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stock = pd.read_csv('S&P500_Stock_Data.csv')
stock
# Out:
#      Interest Rates  Employment  S&P 500 Price
# 0          1.943859   55.413571    2206.680582
# 1          2.258229   59.546305    2486.474488
# 2          2.215863   57.414687    2405.868337
# 3          1.977960   49.908353    2140.434475
# 4          2.437723   52.035492    2411.275663
# ..              ...         ...            ...
# 995        2.528420   52.390828    2578.699184
# 996        2.643571   54.626204    2573.865933
# 997        2.009644   57.004357    2004.911218
# 998        2.201656   62.447790    2344.098981
# 999        2.180638   46.297034    2156.133786
#
# [1000 rows x 3 columns]

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Interest Rates  1000 non-null   float64
#  1   Employment      1000 non-null   float64
#  2   S&P 500 Price   1000 non-null   float64
# dtypes: float64(3)
# memory usage: 23.6 KB

# %%
stock.describe()
# Out:
#        Interest Rates   Employment  S&P 500 Price
# count     1000.000000  1000.000000    1000.000000
# mean         2.195392    56.254855    2319.999936
# std          0.241630     4.862178     193.854745
# min          1.500000    40.000000    1800.000000
# 25%          2.035735    53.029784    2190.447901
# 50%          2.198214    56.160941    2312.443024
# 75%          2.359061    59.422633    2455.764328
# max          3.000000    70.000000    3000.000000

# %%
 #Visualisation aspect

# %%
sns.jointplot(x='Employment', y='S&P 500 Price', data =stock)

# %%
#Ploting Interest Rates & S&P 500 Price

# %%
sns.jointplot(x='Interest Rates', y='S&P 500 Price', data =stock)

# %%
#Using pairplot

# %%
sns.pairplot(stock)

# %%
## CREATING TESTING AND TRAINING DATASET/DATA CLEANING

# %%
y =stock ['S&P 500 Price']
y
# Out:
# 0      2206.680582
# 1      2486.474488
# 2      2405.868337
# 3      2140.434475
# 4      2411.275663
#           ...
# 995    2578.699184
# 996    2573.865933
# 997    2004.911218
# 998    2344.098981
# 999    2156.133786
# Name: S&P 500 Price, Length: 1000, dtype: float64

# %%
x = stock[['Interest Rates', 'Employment']]
x
# Out:
#      Interest Rates  Employment
# 0          1.943859   55.413571
# 1          2.258229   59.546305
# 2          2.215863   57.414687
# 3          1.977960   49.908353
# 4          2.437723   52.035492
# ..              ...         ...
# 995        2.528420   52.390828
# 996        2.643571   54.626204
# 997        2.009644   57.004357
# 998        2.201656   62.447790
# 999        2.180638   46.297034
#
# [1000 rows x 2 columns]

# %%
#using 80% of the Data for Training and 20% for Testing. Using SK LEARN

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size =0.2)

# %%
X_train
# Out:
#      Interest Rates  Employment
# 977        2.186663   55.276936
# 765        1.699832   57.255590
# 862        2.383900   58.575763
# 241        2.513460   52.888007
# 742        2.457031   59.553196
# ..              ...         ...
# 463        2.081659   50.336129
# 67         2.402100   50.326661
# 551        1.899332   62.960713
# 252        2.410757   59.059701
# 704        2.283374   53.753130
#
# [800 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
y_test
# Out:
# 544    2245.261305
# 898    2216.204284
# 980    2245.594050
# 179    2351.681943
# 53     2266.485265
#           ...
# 75     2152.663792
# 499    2234.630350
# 783    2604.705284
# 452    2040.177960
# 693    2441.164248
# Name: S&P 500 Price, Length: 200, dtype: float64

# %%
y_train
# Out:
# 977    2224.040699
# 765    2014.227589
# 862    2493.427910
# 241    2443.871948
# 742    2514.448514
#           ...
# 463    2149.177712
# 67     2380.185822
# 551    2164.735501
# 252    2625.632502
# 704    2403.345743
# Name: S&P 500 Price, Length: 800, dtype: float64

# %%
# Model Testing and EValuation

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression(fit_intercept = True)

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficies (m)', regressor.coef_)
# Out:
# Linear Model Coefficies (m) [728.55081191  11.95220677]

# %%
print('Linear Model Coefficies (m)', regressor.intercept_)
# Out:
# Linear Model Coefficies (m) 49.54365734257726

# %%
#Evaluating the model

# %%
y_predict = regressor.predict(X_test)
y_predict
# Out:
# array([2226.11324724, 2220.83738487, 2211.64192853, 2406.14968697,
#        2313.1051211 , 2117.35249602, 2310.70441796, 2369.58147851,
#        2269.81665073, 2312.16642843, 2479.61517496, 2498.65026687,
#        2115.6723241 , 2510.20493883, 2819.10740943, 2556.9955394 ,
#        2188.68961639, 2389.80372951, 2091.80370279, 2059.37956751,
#        2018.63670539, 2154.68763656, 2495.39787238, 2353.47028422,
#        2132.7292049 , 2521.68908272, 2420.63708143, 2299.13319674,
#        1921.55172566, 2152.49833646, 2093.64166084, 2305.16393278,
#        2340.32354491, 2130.8373941 , 2101.78768829, 2392.79679837,
#        2459.4927715 , 2578.58922503, 2400.55488286, 2396.82487841,
#        2272.78790017, 2143.5835959 , 2219.40251102, 2341.37731736,
#        2299.82331425, 2529.87515106, 1849.43837419, 2028.78595965,
#        2194.34702425, 2434.48939486, 2271.50095773, 2398.9849861 ,
#        2337.45250605, 2522.83338798, 2162.70783154, 2268.42009115,
#        2519.63958859, 2562.80011367, 2248.83346685, 2279.62448724,
#        2554.39076819, 2375.52401867, 2237.83905166, 1864.0964049 ,
#        2474.38980808, 2076.44451231, 2057.11918706, 2389.93919025,
#        2246.25932237, 2150.30813587, 2101.91386213, 1938.03164147,
#        2371.11591761, 2661.30429447, 2171.66152666, 2511.81757506,
#        2192.71034329, 2652.88459872, 2066.33285691, 2168.23534139,
#        2360.619963  , 2331.50060007, 2109.54720753, 2200.33925893,
#        2148.02087585, 2263.6665343 , 2355.45294621, 2420.50910801,
#        2398.12048947, 1976.09410316, 2411.93144608, 2561.01762146,
#        2433.99471709, 2162.36809973, 2114.13673447, 2472.68048575,
#        2012.29046431, 2477.91095361, 2538.06601832, 2275.27863088,
#        2506.89078365, 2466.10313271, 2533.8826463 , 2412.78733319,
#        1910.12752364, 2410.5455059 , 2401.09978965, 2302.68251428,
#        2551.55961727, 2234.35793248, 2207.57508264, 2354.67451987,
#        2070.04030994, 2336.17188082, 2898.57253248, 2373.20992614,
#        2486.81863507, 2522.37307344, 2209.9211335 , 2357.82154824,
#        2646.03903329, 2306.10448879, 2516.53785644, 2177.265804  ,
#        2133.79612317, 2518.03374436, 2319.2126883 , 2385.8038639 ,
#        2366.93752976, 2149.84946027, 2240.80998695, 2114.84560899,
#        2643.39886833, 2107.67818865, 2335.33141524, 2639.83077042,
#        2336.30579662, 2260.6078081 , 2287.74634584, 2326.7417376 ,
#        2560.20008651, 2153.11536485, 2226.05228216, 2076.2910297 ,
#        2625.06372388, 2595.96568227, 2553.03805797, 2385.37538815,
#        2322.3334966 , 1959.03826917, 2171.68015296, 2347.99157486,
#        2283.04973954, 2063.36364463, 2228.3929436 , 2301.43167317,
#        2213.04893614, 2128.05836895, 2718.05261604, 2126.01513479,
#        2322.16362927, 2524.09155227, 2143.5789589 , 2241.4338199 ,
#        2797.70568   , 2463.1970452 , 2130.28956908, 2487.52774252,
#        2057.90338735, 2196.72953307, 1995.36399893, 2132.2788713 ,
#        2208.24227231, 2396.83551764, 2411.34612368, 2062.42246603,
#        2196.39006474, 2316.03895041, 2272.55907498, 2155.43430147,
#        2058.67486476, 2444.57294311, 2412.00699862, 2081.71863371,
#        2201.7211943 , 2483.39491323, 2517.81241471, 2278.15373057,
#        2374.57906788, 2125.59574524, 2401.90524756, 2375.04778277,
#        2158.3178813 , 2171.77670289, 2188.52485332, 2077.04224064,
#        2220.5152218 , 2489.34630055, 2074.55235003, 2420.98278418])

# %%
### visualise the Results

# %%
plt.scatter(y_test, y_predict, color = 'r')
plt.title('Multiple Linear Regression Prediction')
plt.xlabel('True Value (Ground Truth)')
plt.ylabel('Mode of Prediction')
# Out:
# Text(0, 0.5, 'Mode of Prediction')

# %%
k =X_test.shape[1]
n = len(X_test)

# %%
n
# Out:
# 200

# %%
k
# Out:
# 2

# %%
# Doing Some Mathematics

# %%
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),
                    '.3f'))

MSE =mean_squared_error(y_test, y_predict)
MAE =mean_absolute_error(y_test, y_predict)
r2=r2_score(y_test, y_predict)
adj_r2 = 1-(1-r2) * (n-1)/(n-k-1)
MAPE = np.mean(np.abs((y_test-y_predict)/y_test))*100

# %%
print('RMSE = ', RMSE)
print('MSE = ', MSE)
print('Adjested R2 = ',adj_r2)
print('MAPE= ', MAPE)
# Out:
# RMSE =  57.442
# MSE =  3299.5579867972124
# Adjested R2 =  0.9135899913598857
# MAPE=  2.0463467509822038

# %%
### Visualizing The Results

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x_surf, y_surf = np.meshgrid( np.linspace( stock['Interest Rates'].min(), stock['Interest Rates'].max(), 100),  np.linspace(stock['Employment'].min(), stock['Employment'].max() , 100))

# %%
x_surf.shape
# Out:
# (100, 100)

# %%
onlyX = pd.DataFrame({'Interest Rates' : x_surf.ravel(), 'Employment': y_surf.ravel() })

# %%
onlyX.shape
# Out:
# (10000, 2)

# %%
fittedY = regressor.predict(onlyX)

# %%
fittedY.shape
# Out:
# (10000,)

# %%
fittedY=fittedY.reshape(x_surf.shape)

# %%
fittedY.shape
# Out:
# (100, 100)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter( stock['Interest Rates'], stock['Employment'] , stock['S&P 500 Price'] , c = 'blue', marker ='x'  )
ax.plot_surface(x_surf, y_surf, fittedY, color = 'red', alpha = 0.3)
ax.set_xlabel('Interest Rates')
ax.set_ylabel('Unemployment Rates')
ax.set_zlabel('Stock index price')
# Out:
# Text(0.5, 0, 'Stock index price')
